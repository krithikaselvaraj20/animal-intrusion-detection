# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.5/169.5 kB 43.9 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 51.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 19.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="jpM**************WdU")
project = rf.workspace("krithika-zvzce").project("Animal Detection")
dataset = project.version(1).download("yolov8")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1400/3512985383.py in <cell line: 0>()
#       1 from roboflow import Roboflow
# ----> 2 rf = Roboflow(api_key="jpM**************WdU")
#       3 project = rf.workspace("krithika-zvzce").project("Animal Detection")
#       4 dataset = project.version(1).download("yolov8")
#
# /usr/local/lib/python3.12/dist-packages/roboflow/__init__.py in __init__(self, api_key, model_format, notebook)
#     210         self.notebook = notebook
#     211         self.onboarding = False
# --> 212         self.auth()
#     213
#     214     def auth(self):
#
# /usr/local/lib/python3.12/dist-packages/roboflow/__init__.py in auth(self)
#     213
#     214     def auth(self):
# --> 215         r = check_key(self.api_key, self.model_format, self.notebook)
#     216
#     217         if r == "onboarding":
#
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="jpMByNgdDpWu6CFYEWdU")
project = rf.workspace("krithika-zvzce").project("Animal Detection")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# RoboflowError                             Traceback (most recent call last)
# /tmp/ipykernel_1400/1868659015.py in <cell line: 0>()
#       1 from roboflow import Roboflow
#       2 rf = Roboflow(api_key="jpMByNgdDpWu6CFYEWdU")
# ----> 3 project = rf.workspace("krithika-zvzce").project("Animal Detection")
#       4 dataset = project.version(1).download("yolov8")
#
# /usr/local/lib/python3.12/dist-packages/roboflow/core/workspace.py in project(self, project_id)
#      96             raise RuntimeError(f"The {project_id} project is not available in this ({self.url}) workspace")
#      97
# ---> 98         dataset_info = rfapi.get_project(self.__api_key, self.url, project_id)
#      99         dataset_info = dataset_info["project"]
#     100
#
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="YOUR_API_KEY")

project = rf.workspace("krithika-zvzce").project("animal-detection-8rvab")

dataset = project.version(4).download("yolov8")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=undefined&ref=undefined
# loading Roboflow workspace...
# ---------------------------------------------------------------------------
# RoboflowError                             Traceback (most recent call last)
# /tmp/ipykernel_1400/1277050271.py in <cell line: 0>()
#       3 rf = Roboflow(api_key="YOUR_API_KEY")
#       4
# ----> 5 project = rf.workspace("krithika-zvzce").project("animal-detection-8rvab")
#       6
#       7 dataset = project.version(4).download("yolov8")
#
# /usr/local/lib/python3.12/dist-packages/roboflow/__init__.py in workspace(self, the_workspace)
#     236         if self.api_key:  # Check if api_key was passed during __init__
#     237             api_key = self.api_key
# --> 238             list_projects = rfapi.get_workspace(api_key, the_workspace)
#     239             return Workspace(list_projects, api_key, the_workspace, self.model_format)
#     240
#
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="YOUR_API_KEY")

project = rf.workspace("krithika-zvzce").project("animal-detection-8rvab")

dataset = project.version(4).download("yolov8")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=undefined&ref=undefined
# loading Roboflow workspace...
# ---------------------------------------------------------------------------
# RoboflowError                             Traceback (most recent call last)
# /tmp/ipykernel_1400/1277050271.py in <cell line: 0>()
#       3 rf = Roboflow(api_key="YOUR_API_KEY")
#       4
# ----> 5 project = rf.workspace("krithika-zvzce").project("animal-detection-8rvab")
#       6
#       7 dataset = project.version(4).download("yolov8")
#
# /usr/local/lib/python3.12/dist-packages/roboflow/__init__.py in workspace(self, the_workspace)
#     236         if self.api_key:  # Check if api_key was passed during __init__
#     237             api_key = self.api_key
# --> 238             list_projects = rfapi.get_workspace(api_key, the_workspace)
#     239             return Workspace(list_projects, api_key, the_workspace, self.model_format)
#     240
#
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="jpMByNgdDpWu6CFYEWdU")

project = rf.workspace("krithika-zvzce").project("animal-detection-8rvab")
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 78.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to Animal-Detection-4 in yolov8:: 100%|██████████| 5381/5381 [00:01<00:00, 2835.68it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 316.9 kB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# Animal-Detection-4  sample_data

# %%
# !ls Animal-Detection-4
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # small & fast

model.train(
    data="/content/animal-detection-4/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1400/2958402910.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 model = YOLO("yolov8n.pt")  # small & fast
#       4
#       5 model.train(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/__init__.py in <module>
#      11     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
#      12
# ---> 13 from ultralytics.utils import ASSETS, SETTINGS
#      14 from ultralytics.utils.checks import check_yolo as checks
#      15 from ultralytics.utils.downloads import download
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/__init__.py in <module>
#      24 import cv2
#      25 import numpy as np
# ---> 26 import torch
#      27
#      28 from ultralytics import __version__
#
# ...

# %%
from ultralytics import YOLO

# load YOLOv8 model (small version)
model = YOLO("yolov8n.pt")

# train using your dataset
model.train(
    data="/content/Animal-Detection-4/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1400/2881708922.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 # load YOLOv8 model (small version)
#       4 model = YOLO("yolov8n.pt")
#       5
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/__init__.py in <module>
#      11     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
#      12
# ---> 13 from ultralytics.utils import ASSETS, SETTINGS
#      14 from ultralytics.utils.checks import check_yolo as checks
#      15 from ultralytics.utils.downloads import download
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/__init__.py in <module>
#      24 import cv2
#      25 import numpy as np
# ---> 26 import torch
#      27
#      28 from ultralytics import __version__
#
# ...

# %%
# !pip install ultralytics torch torchvision torchaudio

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="jpMByNgdDpWu6CFYEWdU")

project = rf.workspace("krithika-zvzce").project("animal-detection-8rvab")

dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/Animal-Detection-4/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.36 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.5/169.5 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 38.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 49.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="jpMByNgdDpWu6CFYEWdU")

project = rf.workspace("krithika-zvzce").project("animal-detection-8rvab")

dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Animal-Detection-4 in yolov8:: 100%|██████████| 5381/5381 [00:00<00:00, 5510.07it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/Animal-Detection-4/data.yaml",
    epochs=20,        # enough
    imgsz=416,        # faster
    batch=16,
    device=0          # GPU
)
# Out:
# ...
# Ultralytics 8.4.36 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files
files.download('runs/detect/train/weights/best.pt')
